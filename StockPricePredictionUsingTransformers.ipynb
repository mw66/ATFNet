# %% [markdown]
# <a href="https://colab.research.google.com/github/mw66/ATFNet/blob/main/StockPricePredictionUsingTransformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Input, Dense, Dropout, LayerNormalization, MultiHeadAttention, Add, GlobalAveragePooling1D

import yfinance as yf

# %%
def calculate_bollinger_bands(data, window=10, num_of_std=2):
    """Calculate Bollinger Bands"""
    rolling_mean = data.rolling(window=window).mean()
    rolling_std = data.rolling(window=window).std()
    upper_band = rolling_mean + (rolling_std * num_of_std)
    lower_band = rolling_mean - (rolling_std * num_of_std)
    return upper_band, lower_band

def calculate_rsi(data, window=10):
    """Calculate Relative Strength Index"""
    delta = data.diff()
    gain = delta.clip(lower=0)
    loss = -delta.clip(upper=0)
    avg_gain = gain.rolling(window=window, min_periods=1).mean()
    avg_loss = loss.rolling(window=window, min_periods=1).mean()
    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

def calculate_roc(data, periods=10):
    """Calculate Rate of Change."""
    roc = ((data - data.shift(periods)) / data.shift(periods)) * 100
    return roc

# %%
tickers = ['META', 'AAPL', 'MSFT', 'AMZN', 'GOOG']

# %%
ticker_data_frames = []
stats = {}
for ticker in tickers:

    # Download historical data for the ticker
    data = yf.download(ticker, period="1mo", interval="5m")

    # Calculate the daily percentage change
    close = data['Close']
    upper, lower = calculate_bollinger_bands(close, window=14, num_of_std=2)
    width = upper - lower
    rsi = calculate_rsi(close, window=14)
    roc = calculate_roc(close, periods=14)
    volume = data['Volume']
    diff = data['Close'].diff(1)
    percent_change_close = data['Close'].pct_change() * 100

    # Create a DataFrame for the current ticker and append it to the list
    ticker_df = pd.DataFrame({
        ticker+'_close': close,
        ticker+'_width': width,
        ticker+'_rsi': rsi,
        ticker+'_roc': roc,
        ticker+'_volume': volume,
        ticker+'_diff': diff,
        ticker+'_percent_change_close': percent_change_close,
    })

    MEAN = ticker_df.mean()
    STD = ticker_df.std()

    # Keep track of mean and std
    for column in MEAN.index:
      stats[f"{column}_mean"] = MEAN[column]
      stats[f"{column}_std"] = STD[column]

    # Normalize the training features
    ticker_df = (ticker_df - MEAN) / STD

    ticker_data_frames.append(ticker_df)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# Convert stats from dict to df
stats = pd.DataFrame([stats], index=[0])
stats.head()
# Out:
#    META_close_mean  META_close_std  META_width_mean  META_width_std  \
# 0       471.597538        6.565536         4.044216        3.347639
#
#    META_rsi_mean  META_rsi_std  META_roc_mean  META_roc_std  META_volume_mean  \
# 0      52.046993     17.769852        0.06741      0.662438     129860.293878
#
#    META_volume_std  ...  GOOG_rsi_mean  GOOG_rsi_std  GOOG_roc_mean  \
# 0    127656.136644  ...      51.508758     18.269448       0.037538
#
#    GOOG_roc_std  GOOG_volume_mean  GOOG_volume_std  GOOG_diff_mean  \
# 0      0.521079     169079.022741    199817.135336        0.004816
#
#    GOOG_diff_std  GOOG_percent_change_close_mean  \
# 0       0.257919                        0.002896
#
#    GOOG_percent_change_close_std
# 0                       0.148673
#
# [1 rows x 70 columns]

# %%
# Concatenate all ticker DataFrames
df = pd.concat(ticker_data_frames, axis=1)
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)
df.head()
# Out:
#                            META_close  META_width  META_rsi  META_roc  \
# Datetime
# 2024-05-06 10:45:00-04:00   -2.343378   -0.263856 -0.191499 -0.163940
# 2024-05-06 10:50:00-04:00   -2.197464   -0.153155  0.191034  0.179434
# 2024-05-06 10:55:00-04:00   -2.128164   -0.051378  0.107289  0.095626
# 2024-05-06 11:00:00-04:00   -2.147217    0.084253  0.408600  0.321744
# 2024-05-06 11:05:00-04:00   -1.938538    0.426052  1.098261  0.986049
#
#                            META_volume  META_diff  META_percent_change_close  \
# Datetime
# 2024-05-06 10:45:00-04:00     0.197356   0.360105                   0.373423
# 2024-05-06 10:50:00-04:00     0.727836   1.205440                   1.248196
# 2024-05-06 10:55:00-04:00    -0.034243   0.557242                   0.575949
# 2024-05-06 11:00:00-04:00     1.357739  -0.190252                  -0.196026
# 2024-05-06 11:05:00-04:00     0.416155   1.736449                   1.792720
#
#                            AAPL_close  AAPL_width  AAPL_rsi  ...  AMZN_volume  \
# Datetime                                                     ...
# 2024-05-06 10:45:00-04:00   -1.601708    0.617707 -0.668180  ...    -0.151487
# 2024-05-06 10:50:00-04:00   -1.622586    0.244471 -0.670999  ...     0.057968
# 2024-05-06 10:55:00-04:00   -1.636098    0.240101 -0.067319  ...    -0.005407
# 2024-05-06 11:00:00-04:00   -1.752784    0.386967 -0.444032  ...     0.007689
# 2024-05-06 11:05:00-04:00   -1.744185    0.214880  0.097236  ...     0.008485
#
#                            AMZN_diff  AMZN_percent_change_close  GOOG_close  \
# Datetime
# 2024-05-06 10:45:00-04:00   0.762600                   0.748632   -1.829905
# 2024-05-06 10:50:00-04:00   0.049679                   0.048219   -1.784604
# 2024-05-06 10:55:00-04:00   0.880625                   0.863661   -1.834591
# 2024-05-06 11:00:00-04:00   0.326802                   0.319803   -1.834591
# 2024-05-06 11:05:00-04:00   0.999737                   0.978990   -1.764297
#
#                            GOOG_width  GOOG_rsi  GOOG_roc  GOOG_volume  \
# Datetime
# 2024-05-06 10:45:00-04:00    0.833653 -0.421623 -0.560886     0.019813
# 2024-05-06 10:50:00-04:00    0.782042 -0.728739 -0.916822    -0.160782
# 2024-05-06 10:55:00-04:00    0.695553 -0.921164 -1.193926    -0.152540
# 2024-05-06 11:00:00-04:00    0.252575 -1.440789 -1.654698    -0.225767
# 2024-05-06 11:05:00-04:00   -0.282594 -1.020160 -1.175543    -0.266349
#
#                            GOOG_diff  GOOG_percent_change_close
# Datetime
# 2024-05-06 10:45:00-04:00  -0.813504                  -0.837416
# 2024-05-06 10:50:00-04:00   0.543536                   0.559776
# 2024-05-06 10:55:00-04:00  -0.639038                  -0.658105
# 2024-05-06 11:00:00-04:00  -0.018673                  -0.019480
# 2024-05-06 11:05:00-04:00   0.853718                   0.879444
#
# [5 rows x 35 columns]

# %%
# Shift the df data to create labels
labels = df.shift(-1)

# Drop the last row in both percent_change_data and labels as it won't have a corresponding label
df = df.iloc[:-1]
labels = labels.iloc[:-1]

# %%
# Sequence len = 24 means that we have 2 hours of 5 min data
SEQUENCE_LEN = 24

# Function to create X-day sequences for each ticker
def create_sequences(data, labels, mean, std, sequence_length=SEQUENCE_LEN):
    sequences = []
    lab = []
    data_size = len(data)

    # + 12 because we want to predict the next hour
    for i in range(data_size - (sequence_length + 13)):
      if i == 0:
        continue

      sequences.append(data[i:i + sequence_length])
      lab.append([labels[i-1], labels[i + 12], mean[0], std[0]])

    for i in range(0, len(lab)):
      last_price_data = sequences[i][-1][0]
      last_price_label = lab[i][0]

      if not last_price_data == last_price_label:
        print(f"ERROR : {last_price_data=} and {last_price_label=} are not equal")

    return np.array(sequences), np.array(lab)

# %%
sequences_dict = {}
sequence_labels = {}
for ticker in tickers:

    # Extract close and volume data for the ticker
    close = df[ticker+'_close'].values
    width = df[ticker+'_width'].values
    rsi = df[ticker+'_rsi'].values
    roc = df[ticker+'_roc'].values
    volume = df[ticker+'_volume'].values
    diff = df[ticker+'_diff'].values
    pct_change = df[ticker+'_percent_change_close'].values

    # Combine close and volume data
    ticker_data = np.column_stack((close,
                                   width,
                                   rsi,
                                   roc,
                                   volume,
                                   diff,
                                   pct_change))

    # Generate sequences
    attribute = ticker+"_close"
    ticker_sequences, lab = create_sequences(ticker_data,
                                             labels[attribute].values[SEQUENCE_LEN-1:],
                                             stats[attribute+"_mean"].values,
                                             stats[attribute+"_std"].values)

    sequences_dict[ticker] = ticker_sequences
    sequence_labels[ticker] = lab

# %%
# Combine data and labels from all tickers
all_sequences = []
all_labels = []

for ticker in tickers:
    all_sequences.extend(sequences_dict[ticker])
    all_labels.extend(sequence_labels[ticker])

# Convert to numpy arrays
all_sequences = np.array(all_sequences)
all_labels = np.array(all_labels)

# %%
np.random.seed(42)
shuffled_indices = np.random.permutation(len(all_sequences))
all_sequences = all_sequences[shuffled_indices]
all_labels = all_labels[shuffled_indices]

train_size = int(len(all_sequences) * 0.9)

# Split sequences
train_sequences = all_sequences[:train_size]
train_labels    = all_labels[:train_size]

other_sequences = all_sequences[train_size:]
other_labels    = all_labels[train_size:]

shuffled_indices = np.random.permutation(len(other_sequences))
other_sequences = other_sequences[shuffled_indices]
other_labels = other_labels[shuffled_indices]

val_size = int(len(other_sequences) * 0.5)

validation_sequences = other_sequences[:val_size]
validation_labels = other_labels[:val_size]

test_sequences = other_sequences[val_size:]
test_labels = other_labels[val_size:]

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Attention and Normalization
    x = LayerNormalization(epsilon=1e-6)(inputs)
    x = MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x, x)
    x = Add()([x, inputs])

    # Feed Forward Part
    y = LayerNormalization(epsilon=1e-6)(x)
    y = Dense(ff_dim, activation="relu")(y)
    y = Dropout(dropout)(y)
    y = Dense(inputs.shape[-1])(y)
    return Add()([y, x])

def build_transformer_model(input_shape, head_size, num_heads, ff_dim, num_layers, dropout=0):
    inputs = Input(shape=input_shape)
    x = inputs

    # Create multiple layers of the Transformer block
    for _ in range(num_layers):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    # Final part of the model
    x = GlobalAveragePooling1D()(x)
    x = LayerNormalization(epsilon=1e-6)(x)
    outputs = Dense(1, activation="linear")(x)

    # Compile model
    model = Model(inputs=inputs, outputs=outputs)
    return model

# Model parameters
input_shape = train_sequences.shape[1:]
head_size = 256
num_heads = 16
ff_dim = 1024
num_layers = 12
dropout = 0.20

# Build the model
model = build_transformer_model(input_shape, head_size, num_heads, ff_dim, num_layers, dropout)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 24, 7)]              0         []
#
#  layer_normalization (Layer  (None, 24, 7)                14        ['input_1[0][0]']
#  Normalization)
#
#  multi_head_attention (Mult  (None, 24, 7)                126983    ['layer_normalization[0][0]',
#  iHeadAttention)                                                     'layer_normalization[0][0]']
#
#  add (Add)                   (None, 24, 7)                0         ['multi_head_attention[0][0]',
#                                                                      'input_1[0][0]']
#
#  layer_normalization_1 (Lay  (None, 24, 7)                14        ['add[0][0]']
#  erNormalization)
#
#  dense (Dense)               (None, 24, 1024)             8192      ['layer_normalization_1[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 24, 1024)             0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 24, 7)                7175      ['dropout[0][0]']
#
#  add_1 (Add)                 (None, 24, 7)                0         ['dense_1[0][0]',
#                                                                      'add[0][0]']
#
#  layer_normalization_2 (Lay  (None, 24, 7)                14        ['add_1[0][0]']
#  erNormalization)
#
#  multi_head_attention_1 (Mu  (None, 24, 7)                126983    ['layer_normalization_2[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_2[0][0]
#                                                                     ']
#
#  add_2 (Add)                 (None, 24, 7)                0         ['multi_head_attention_1[0][0]
#                                                                     ',
#                                                                      'add_1[0][0]']
#
#  layer_normalization_3 (Lay  (None, 24, 7)                14        ['add_2[0][0]']
#  erNormalization)
#
#  dense_2 (Dense)             (None, 24, 1024)             8192      ['layer_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_1 (Dropout)         (None, 24, 1024)             0         ['dense_2[0][0]']
#
#  dense_3 (Dense)             (None, 24, 7)                7175      ['dropout_1[0][0]']
#
#  add_3 (Add)                 (None, 24, 7)                0         ['dense_3[0][0]',
#                                                                      'add_2[0][0]']
#
#  layer_normalization_4 (Lay  (None, 24, 7)                14        ['add_3[0][0]']
#  erNormalization)
#
#  multi_head_attention_2 (Mu  (None, 24, 7)                126983    ['layer_normalization_4[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_4[0][0]
#                                                                     ']
#
#  add_4 (Add)                 (None, 24, 7)                0         ['multi_head_attention_2[0][0]
#                                                                     ',
#                                                                      'add_3[0][0]']
#
#  layer_normalization_5 (Lay  (None, 24, 7)                14        ['add_4[0][0]']
#  erNormalization)
#
#  dense_4 (Dense)             (None, 24, 1024)             8192      ['layer_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 24, 1024)             0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 24, 7)                7175      ['dropout_2[0][0]']
#
#  add_5 (Add)                 (None, 24, 7)                0         ['dense_5[0][0]',
#                                                                      'add_4[0][0]']
#
#  layer_normalization_6 (Lay  (None, 24, 7)                14        ['add_5[0][0]']
#  erNormalization)
#
#  multi_head_attention_3 (Mu  (None, 24, 7)                126983    ['layer_normalization_6[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_6[0][0]
#                                                                     ']
#
#  add_6 (Add)                 (None, 24, 7)                0         ['multi_head_attention_3[0][0]
#                                                                     ',
#                                                                      'add_5[0][0]']
#
#  layer_normalization_7 (Lay  (None, 24, 7)                14        ['add_6[0][0]']
#  erNormalization)
#
#  dense_6 (Dense)             (None, 24, 1024)             8192      ['layer_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_3 (Dropout)         (None, 24, 1024)             0         ['dense_6[0][0]']
#
#  dense_7 (Dense)             (None, 24, 7)                7175      ['dropout_3[0][0]']
#
#  add_7 (Add)                 (None, 24, 7)                0         ['dense_7[0][0]',
#                                                                      'add_6[0][0]']
#
#  layer_normalization_8 (Lay  (None, 24, 7)                14        ['add_7[0][0]']
#  erNormalization)
#
#  multi_head_attention_4 (Mu  (None, 24, 7)                126983    ['layer_normalization_8[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_8[0][0]
#                                                                     ']
#
#  add_8 (Add)                 (None, 24, 7)                0         ['multi_head_attention_4[0][0]
#                                                                     ',
#                                                                      'add_7[0][0]']
#
#  layer_normalization_9 (Lay  (None, 24, 7)                14        ['add_8[0][0]']
#  erNormalization)
#
#  dense_8 (Dense)             (None, 24, 1024)             8192      ['layer_normalization_9[0][0]'
#                                                                     ]
#
#  dropout_4 (Dropout)         (None, 24, 1024)             0         ['dense_8[0][0]']
#
#  dense_9 (Dense)             (None, 24, 7)                7175      ['dropout_4[0][0]']
#
#  add_9 (Add)                 (None, 24, 7)                0         ['dense_9[0][0]',
#                                                                      'add_8[0][0]']
#
#  layer_normalization_10 (La  (None, 24, 7)                14        ['add_9[0][0]']
#  yerNormalization)
#
#  multi_head_attention_5 (Mu  (None, 24, 7)                126983    ['layer_normalization_10[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_10[0][0]
#                                                                     ']
#
#  add_10 (Add)                (None, 24, 7)                0         ['multi_head_attention_5[0][0]
#                                                                     ',
#                                                                      'add_9[0][0]']
#
#  layer_normalization_11 (La  (None, 24, 7)                14        ['add_10[0][0]']
#  yerNormalization)
#
#  dense_10 (Dense)            (None, 24, 1024)             8192      ['layer_normalization_11[0][0]
#                                                                     ']
#
#  dropout_5 (Dropout)         (None, 24, 1024)             0         ['dense_10[0][0]']
#
#  dense_11 (Dense)            (None, 24, 7)                7175      ['dropout_5[0][0]']
#
#  add_11 (Add)                (None, 24, 7)                0         ['dense_11[0][0]',
#                                                                      'add_10[0][0]']
#
#  layer_normalization_12 (La  (None, 24, 7)                14        ['add_11[0][0]']
#  yerNormalization)
#
#  multi_head_attention_6 (Mu  (None, 24, 7)                126983    ['layer_normalization_12[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_12[0][0]
#                                                                     ']
#
#  add_12 (Add)                (None, 24, 7)                0         ['multi_head_attention_6[0][0]
#                                                                     ',
#                                                                      'add_11[0][0]']
#
#  layer_normalization_13 (La  (None, 24, 7)                14        ['add_12[0][0]']
#  yerNormalization)
#
#  dense_12 (Dense)            (None, 24, 1024)             8192      ['layer_normalization_13[0][0]
#                                                                     ']
#
#  dropout_6 (Dropout)         (None, 24, 1024)             0         ['dense_12[0][0]']
#
#  dense_13 (Dense)            (None, 24, 7)                7175      ['dropout_6[0][0]']
#
#  add_13 (Add)                (None, 24, 7)                0         ['dense_13[0][0]',
#                                                                      'add_12[0][0]']
#
#  layer_normalization_14 (La  (None, 24, 7)                14        ['add_13[0][0]']
#  yerNormalization)
#
#  multi_head_attention_7 (Mu  (None, 24, 7)                126983    ['layer_normalization_14[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_14[0][0]
#                                                                     ']
#
#  add_14 (Add)                (None, 24, 7)                0         ['multi_head_attention_7[0][0]
#                                                                     ',
#                                                                      'add_13[0][0]']
#
#  layer_normalization_15 (La  (None, 24, 7)                14        ['add_14[0][0]']
#  yerNormalization)
#
#  dense_14 (Dense)            (None, 24, 1024)             8192      ['layer_normalization_15[0][0]
#                                                                     ']
#
#  dropout_7 (Dropout)         (None, 24, 1024)             0         ['dense_14[0][0]']
#
#  dense_15 (Dense)            (None, 24, 7)                7175      ['dropout_7[0][0]']
#
#  add_15 (Add)                (None, 24, 7)                0         ['dense_15[0][0]',
#                                                                      'add_14[0][0]']
#
#  layer_normalization_16 (La  (None, 24, 7)                14        ['add_15[0][0]']
#  yerNormalization)
#
#  multi_head_attention_8 (Mu  (None, 24, 7)                126983    ['layer_normalization_16[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_16[0][0]
#                                                                     ']
#
#  add_16 (Add)                (None, 24, 7)                0         ['multi_head_attention_8[0][0]
#                                                                     ',
#                                                                      'add_15[0][0]']
#
#  layer_normalization_17 (La  (None, 24, 7)                14        ['add_16[0][0]']
#  yerNormalization)
#
#  dense_16 (Dense)            (None, 24, 1024)             8192      ['layer_normalization_17[0][0]
#                                                                     ']
#
#  dropout_8 (Dropout)         (None, 24, 1024)             0         ['dense_16[0][0]']
#
#  dense_17 (Dense)            (None, 24, 7)                7175      ['dropout_8[0][0]']
#
#  add_17 (Add)                (None, 24, 7)                0         ['dense_17[0][0]',
#                                                                      'add_16[0][0]']
#
#  layer_normalization_18 (La  (None, 24, 7)                14        ['add_17[0][0]']
#  yerNormalization)
#
#  multi_head_attention_9 (Mu  (None, 24, 7)                126983    ['layer_normalization_18[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_18[0][0]
#                                                                     ']
#
#  add_18 (Add)                (None, 24, 7)                0         ['multi_head_attention_9[0][0]
#                                                                     ',
#                                                                      'add_17[0][0]']
#
#  layer_normalization_19 (La  (None, 24, 7)                14        ['add_18[0][0]']
#  yerNormalization)
#
#  dense_18 (Dense)            (None, 24, 1024)             8192      ['layer_normalization_19[0][0]
#                                                                     ']
#
#  dropout_9 (Dropout)         (None, 24, 1024)             0         ['dense_18[0][0]']
#
#  dense_19 (Dense)            (None, 24, 7)                7175      ['dropout_9[0][0]']
#
#  add_19 (Add)                (None, 24, 7)                0         ['dense_19[0][0]',
#                                                                      'add_18[0][0]']
#
#  layer_normalization_20 (La  (None, 24, 7)                14        ['add_19[0][0]']
#  yerNormalization)
#
#  multi_head_attention_10 (M  (None, 24, 7)                126983    ['layer_normalization_20[0][0]
#  ultiHeadAttention)                                                 ',
#                                                                      'layer_normalization_20[0][0]
#                                                                     ']
#
#  add_20 (Add)                (None, 24, 7)                0         ['multi_head_attention_10[0][0
#                                                                     ]',
#                                                                      'add_19[0][0]']
#
#  layer_normalization_21 (La  (None, 24, 7)                14        ['add_20[0][0]']
#  yerNormalization)
#
#  dense_20 (Dense)            (None, 24, 1024)             8192      ['layer_normalization_21[0][0]
#                                                                     ']
#
#  dropout_10 (Dropout)        (None, 24, 1024)             0         ['dense_20[0][0]']
#
#  dense_21 (Dense)            (None, 24, 7)                7175      ['dropout_10[0][0]']
#
#  add_21 (Add)                (None, 24, 7)                0         ['dense_21[0][0]',
#                                                                      'add_20[0][0]']
#
#  layer_normalization_22 (La  (None, 24, 7)                14        ['add_21[0][0]']
#  yerNormalization)
#
#  multi_head_attention_11 (M  (None, 24, 7)                126983    ['layer_normalization_22[0][0]
#  ultiHeadAttention)                                                 ',
#                                                                      'layer_normalization_22[0][0]
#                                                                     ']
#
#  add_22 (Add)                (None, 24, 7)                0         ['multi_head_attention_11[0][0
#                                                                     ]',
#                                                                      'add_21[0][0]']
#
#  layer_normalization_23 (La  (None, 24, 7)                14        ['add_22[0][0]']
#  yerNormalization)
#
#  dense_22 (Dense)            (None, 24, 1024)             8192      ['layer_normalization_23[0][0]
#                                                                     ']
#
#  dropout_11 (Dropout)        (None, 24, 1024)             0         ['dense_22[0][0]']
#
#  dense_23 (Dense)            (None, 24, 7)                7175      ['dropout_11[0][0]']
#
#  add_23 (Add)                (None, 24, 7)                0         ['dense_23[0][0]',
#                                                                      'add_22[0][0]']
#
#  global_average_pooling1d (  (None, 7)                    0         ['add_23[0][0]']
#  GlobalAveragePooling1D)
#
#  layer_normalization_24 (La  (None, 7)                    14        ['global_average_pooling1d[0][
#  yerNormalization)                                                  0]']
#
#  dense_24 (Dense)            (None, 1)                    8         ['layer_normalization_24[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 1708558 (6.52 MB)
# Trainable params: 1708558 (6.52 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
def custom_mae_loss(y_true, y_pred):
    y_true_next = tf.cast(y_true[:, 1], tf.float64)
    y_pred_next = tf.cast(y_pred[:, 0], tf.float64)
    abs_error = tf.abs(y_true_next - y_pred_next)

    return tf.reduce_mean(abs_error)

def dir_acc(y_true, y_pred):
    mean, std = tf.cast(y_true[:, 2], tf.float64), tf.cast(y_true[:, 3], tf.float64)

    y_true_prev = (tf.cast(y_true[:, 0], tf.float64) * std) + mean
    y_true_next = (tf.cast(y_true[:, 1], tf.float64) * std) + mean
    y_pred_next = (tf.cast(y_pred[:, 0], tf.float64) * std) + mean

    true_change = y_true_next - y_true_prev
    pred_change = y_pred_next - y_true_prev

    correct_direction = tf.equal(tf.sign(true_change), tf.sign(pred_change))

    return tf.reduce_mean(tf.cast(correct_direction, tf.float64))

# %%
# Compile the model
optimizer = tf.keras.optimizers.Adam()
model.compile(optimizer=optimizer, loss=custom_mae_loss, metrics=[dir_acc])

# %%
# Define a callback to save the best model
checkpoint_callback_train = ModelCheckpoint(
    "transformer_train_model.keras",  # Filepath to save the best model
    monitor="dir_acc",  #"loss",  # Metric to monitor
    save_best_only=True,  # Save only the best model
    mode="max",  # Minimize the monitored metric
    verbose=1,  # Display progress
)

# Define a callback to save the best model
checkpoint_callback_val = ModelCheckpoint(
    "transformer_val_model.keras",  # Filepath to save the best model
    monitor="val_dir_acc", #"val_loss",  # Metric to monitor
    save_best_only=True,  # Save only the best model
    mode="max",  # Minimize the monitored metric
    verbose=1,  # Display progress
)

def get_lr_callback(batch_size=16, mode='cos', epochs=500, plot=False):
    lr_start, lr_max, lr_min = 0.0001, 0.005, 0.00001  # Adjust learning rate boundaries
    lr_ramp_ep = int(0.30 * epochs)  # 30% of epochs for warm-up
    lr_sus_ep = max(0, int(0.10 * epochs) - lr_ramp_ep)  # Optional sustain phase, adjust as needed

    def lrfn(epoch):
        if epoch < lr_ramp_ep:  # Warm-up phase
            lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start
        elif epoch < lr_ramp_ep + lr_sus_ep:  # Sustain phase at max learning rate
            lr = lr_max
        elif mode == 'cos':
            decay_total_epochs, decay_epoch_index = epochs - lr_ramp_ep - lr_sus_ep, epoch - lr_ramp_ep - lr_sus_ep
            phase = math.pi * decay_epoch_index / decay_total_epochs
            lr = (lr_max - lr_min) * 0.5 * (1 + math.cos(phase)) + lr_min
        else:
            lr = lr_min  # Default to minimum learning rate if mode is not recognized

        return lr

    if plot:  # Plot learning rate curve if plot is True
        plt.figure(figsize=(10, 5))
        plt.plot(np.arange(epochs), [lrfn(epoch) for epoch in np.arange(epochs)], marker='o')
        plt.xlabel('Epoch')
        plt.ylabel('Learning Rate')
        plt.title('Learning Rate Scheduler')
        plt.show()

    return tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=True)

# %%
BATCH_SIZE = 64
EPOCHS = 100
model.fit(train_sequences, train_labels,
          validation_data=(validation_sequences, validation_labels),
          epochs=EPOCHS,
          batch_size=BATCH_SIZE,
          shuffle=True,
          callbacks=[checkpoint_callback_train, checkpoint_callback_val, get_lr_callback(batch_size=BATCH_SIZE, epochs=EPOCHS)])
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 1/100
# 324/324 [==============================] - ETA: 0s - loss: 0.2299 - dir_acc: 0.5319
# Epoch 1: dir_acc improved from -inf to 0.53193, saving model to transformer_train_model.keras
#
# Epoch 1: val_dir_acc improved from -inf to 0.54738, saving model to transformer_val_model.keras
# 324/324 [==============================] - 86s 160ms/step - loss: 0.2299 - dir_acc: 0.5319 - val_loss: 0.1961 - val_dir_acc: 0.5474 - lr: 1.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.00026333333333333336.
# Epoch 2/100
# 324/324 [==============================] - ETA: 0s - loss: 0.2117 - dir_acc: 0.5296
# Epoch 2: dir_acc did not improve from 0.53193
#
# Epoch 2: val_dir_acc improved from 0.54738 to 0.57509, saving model to transformer_val_model.keras
# 324/324 [==============================] - 50s 153ms/step - loss: 0.2117 - dir_acc: 0.5296 - val_loss: 0.1745 - val_dir_acc: 0.5751 - lr: 2.6333e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.00042666666666666667.
# Epoch 3/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1984 - dir_acc: 0.5356
# Epoch 3: dir_acc improved from 0.53193 to 0.53563, saving model to transformer_train_model.keras
#
# Epoch 3: val_dir_acc did not improve from 0.57509
# 324/324 [==============================] - 49s 153ms/step - loss: 0.1984 - dir_acc: 0.5356 - val_loss: 0.1773 - val_dir_acc: 0.5734 - lr: 4.2667e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.00059.
# Epoch 4/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1914 - dir_acc: 0.5376
# Epoch 4: dir_acc improved from 0.53563 to 0.53756, saving model to transformer_train_model.keras
#
# Epoch 4: val_dir_acc did not improve from 0.57509
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1914 - dir_acc: 0.5376 - val_loss: 0.1634 - val_dir_acc: 0.5734 - lr: 5.9000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0007533333333333334.
# Epoch 5/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1903 - dir_acc: 0.5310
# Epoch 5: dir_acc did not improve from 0.53756
#
# Epoch 5: val_dir_acc did not improve from 0.57509
# 324/324 [==============================] - 49s 150ms/step - loss: 0.1903 - dir_acc: 0.5310 - val_loss: 0.2107 - val_dir_acc: 0.5247 - lr: 7.5333e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0009166666666666668.
# Epoch 6/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1860 - dir_acc: 0.5335
# Epoch 6: dir_acc did not improve from 0.53756
#
# Epoch 6: val_dir_acc did not improve from 0.57509
# 324/324 [==============================] - 49s 150ms/step - loss: 0.1860 - dir_acc: 0.5335 - val_loss: 0.2000 - val_dir_acc: 0.5647 - lr: 9.1667e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.00108.
# Epoch 7/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1808 - dir_acc: 0.5411
# Epoch 7: dir_acc improved from 0.53756 to 0.54109, saving model to transformer_train_model.keras
#
# Epoch 7: val_dir_acc did not improve from 0.57509
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1808 - dir_acc: 0.5411 - val_loss: 0.1738 - val_dir_acc: 0.5665 - lr: 0.0011
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0012433333333333335.
# Epoch 8/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1810 - dir_acc: 0.5377
# Epoch 8: dir_acc did not improve from 0.54109
#
# Epoch 8: val_dir_acc improved from 0.57509 to 0.57598, saving model to transformer_val_model.keras
# 324/324 [==============================] - 50s 154ms/step - loss: 0.1810 - dir_acc: 0.5377 - val_loss: 0.1574 - val_dir_acc: 0.5760 - lr: 0.0012
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0014066666666666667.
# Epoch 9/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1715 - dir_acc: 0.5463
# Epoch 9: dir_acc improved from 0.54109 to 0.54632, saving model to transformer_train_model.keras
#
# Epoch 9: val_dir_acc did not improve from 0.57598
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1715 - dir_acc: 0.5463 - val_loss: 0.1596 - val_dir_acc: 0.5708 - lr: 0.0014
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.00157.
# Epoch 10/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1680 - dir_acc: 0.5569
# Epoch 10: dir_acc improved from 0.54632 to 0.55688, saving model to transformer_train_model.keras
#
# Epoch 10: val_dir_acc improved from 0.57598 to 0.57682, saving model to transformer_val_model.keras
# 324/324 [==============================] - 50s 155ms/step - loss: 0.1680 - dir_acc: 0.5569 - val_loss: 0.1620 - val_dir_acc: 0.5768 - lr: 0.0016
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0017333333333333335.
# Epoch 11/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1683 - dir_acc: 0.5539
# Epoch 11: dir_acc did not improve from 0.55688
#
# Epoch 11: val_dir_acc improved from 0.57682 to 0.57775, saving model to transformer_val_model.keras
# 324/324 [==============================] - 50s 153ms/step - loss: 0.1683 - dir_acc: 0.5539 - val_loss: 0.1533 - val_dir_acc: 0.5778 - lr: 0.0017
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0018966666666666667.
# Epoch 12/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1693 - dir_acc: 0.5574
# Epoch 12: dir_acc improved from 0.55688 to 0.55736, saving model to transformer_train_model.keras
#
# Epoch 12: val_dir_acc did not improve from 0.57775
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1693 - dir_acc: 0.5574 - val_loss: 0.2126 - val_dir_acc: 0.5639 - lr: 0.0019
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0020599999999999998.
# Epoch 13/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1727 - dir_acc: 0.5542
# Epoch 13: dir_acc did not improve from 0.55736
#
# Epoch 13: val_dir_acc improved from 0.57775 to 0.57859, saving model to transformer_val_model.keras
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1727 - dir_acc: 0.5542 - val_loss: 0.1603 - val_dir_acc: 0.5786 - lr: 0.0021
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0022233333333333332.
# Epoch 14/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1711 - dir_acc: 0.5606
# Epoch 14: dir_acc improved from 0.55736 to 0.56064, saving model to transformer_train_model.keras
#
# Epoch 14: val_dir_acc improved from 0.57859 to 0.59251, saving model to transformer_val_model.keras
# 324/324 [==============================] - 50s 154ms/step - loss: 0.1711 - dir_acc: 0.5606 - val_loss: 0.1601 - val_dir_acc: 0.5925 - lr: 0.0022
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0023866666666666667.
# Epoch 15/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1655 - dir_acc: 0.5578
# Epoch 15: dir_acc did not improve from 0.56064
#
# Epoch 15: val_dir_acc did not improve from 0.59251
# 324/324 [==============================] - 49s 150ms/step - loss: 0.1655 - dir_acc: 0.5578 - val_loss: 0.1641 - val_dir_acc: 0.5813 - lr: 0.0024
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.0025499999999999997.
# Epoch 16/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1639 - dir_acc: 0.5661
# Epoch 16: dir_acc improved from 0.56064 to 0.56611, saving model to transformer_train_model.keras
#
# Epoch 16: val_dir_acc did not improve from 0.59251
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1639 - dir_acc: 0.5661 - val_loss: 0.1590 - val_dir_acc: 0.5639 - lr: 0.0026
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0027133333333333332.
# Epoch 17/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1656 - dir_acc: 0.5632
# Epoch 17: dir_acc did not improve from 0.56611
#
# Epoch 17: val_dir_acc did not improve from 0.59251
# 324/324 [==============================] - 49s 150ms/step - loss: 0.1656 - dir_acc: 0.5632 - val_loss: 0.1574 - val_dir_acc: 0.5657 - lr: 0.0027
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.0028766666666666667.
# Epoch 18/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1651 - dir_acc: 0.5628
# Epoch 18: dir_acc did not improve from 0.56611
#
# Epoch 18: val_dir_acc did not improve from 0.59251
# 324/324 [==============================] - 49s 151ms/step - loss: 0.1651 - dir_acc: 0.5628 - val_loss: 0.1956 - val_dir_acc: 0.5700 - lr: 0.0029
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.0030399999999999997.
# Epoch 19/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1635 - dir_acc: 0.5673
# Epoch 19: dir_acc improved from 0.56611 to 0.56730, saving model to transformer_train_model.keras
#
# Epoch 19: val_dir_acc did not improve from 0.59251
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1635 - dir_acc: 0.5673 - val_loss: 0.1539 - val_dir_acc: 0.5873 - lr: 0.0030
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.003203333333333333.
# Epoch 20/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1602 - dir_acc: 0.5695
# Epoch 20: dir_acc improved from 0.56730 to 0.56951, saving model to transformer_train_model.keras
#
# Epoch 20: val_dir_acc did not improve from 0.59251
# 324/324 [==============================] - 50s 153ms/step - loss: 0.1602 - dir_acc: 0.5695 - val_loss: 0.1498 - val_dir_acc: 0.5925 - lr: 0.0032
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.0033666666666666667.
# Epoch 21/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1618 - dir_acc: 0.5740
# Epoch 21: dir_acc improved from 0.56951 to 0.57404, saving model to transformer_train_model.keras
#
# Epoch 21: val_dir_acc did not improve from 0.59251
# 324/324 [==============================] - 50s 153ms/step - loss: 0.1618 - dir_acc: 0.5740 - val_loss: 0.1555 - val_dir_acc: 0.5873 - lr: 0.0034
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.0035299999999999997.
# Epoch 22/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1566 - dir_acc: 0.5783
# Epoch 22: dir_acc improved from 0.57404 to 0.57826, saving model to transformer_train_model.keras
#
# Epoch 22: val_dir_acc improved from 0.59251 to 0.60122, saving model to transformer_val_model.keras
# 324/324 [==============================] - 50s 155ms/step - loss: 0.1566 - dir_acc: 0.5783 - val_loss: 0.1441 - val_dir_acc: 0.6012 - lr: 0.0035
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.003693333333333333.
# Epoch 23/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1567 - dir_acc: 0.5755
# Epoch 23: dir_acc did not improve from 0.57826
#
# Epoch 23: val_dir_acc did not improve from 0.60122
# 324/324 [==============================] - 49s 151ms/step - loss: 0.1567 - dir_acc: 0.5755 - val_loss: 0.1730 - val_dir_acc: 0.5778 - lr: 0.0037
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.0038566666666666667.
# Epoch 24/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1566 - dir_acc: 0.5776
# Epoch 24: dir_acc did not improve from 0.57826
#
# Epoch 24: val_dir_acc did not improve from 0.60122
# 324/324 [==============================] - 49s 151ms/step - loss: 0.1566 - dir_acc: 0.5776 - val_loss: 0.1631 - val_dir_acc: 0.5882 - lr: 0.0039
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.00402.
# Epoch 25/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1595 - dir_acc: 0.5792
# Epoch 25: dir_acc improved from 0.57826 to 0.57921, saving model to transformer_train_model.keras
#
# Epoch 25: val_dir_acc did not improve from 0.60122
# 324/324 [==============================] - 49s 153ms/step - loss: 0.1595 - dir_acc: 0.5792 - val_loss: 0.1451 - val_dir_acc: 0.6004 - lr: 0.0040
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.004183333333333334.
# Epoch 26/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1557 - dir_acc: 0.5836
# Epoch 26: dir_acc improved from 0.57921 to 0.58363, saving model to transformer_train_model.keras
#
# Epoch 26: val_dir_acc did not improve from 0.60122
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1557 - dir_acc: 0.5836 - val_loss: 0.1457 - val_dir_acc: 0.5891 - lr: 0.0042
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.004346666666666667.
# Epoch 27/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1576 - dir_acc: 0.5759
# Epoch 27: dir_acc did not improve from 0.58363
#
# Epoch 27: val_dir_acc did not improve from 0.60122
# 324/324 [==============================] - 49s 150ms/step - loss: 0.1576 - dir_acc: 0.5759 - val_loss: 0.1470 - val_dir_acc: 0.5995 - lr: 0.0043
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.00451.
# Epoch 28/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1589 - dir_acc: 0.5824
# Epoch 28: dir_acc did not improve from 0.58363
#
# Epoch 28: val_dir_acc improved from 0.60122 to 0.60477, saving model to transformer_val_model.keras
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1589 - dir_acc: 0.5824 - val_loss: 0.1445 - val_dir_acc: 0.6048 - lr: 0.0045
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.004673333333333334.
# Epoch 29/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1568 - dir_acc: 0.5788
# Epoch 29: dir_acc did not improve from 0.58363
#
# Epoch 29: val_dir_acc did not improve from 0.60477
# 324/324 [==============================] - 49s 151ms/step - loss: 0.1568 - dir_acc: 0.5788 - val_loss: 0.1708 - val_dir_acc: 0.5786 - lr: 0.0047
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.004836666666666667.
# Epoch 30/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1613 - dir_acc: 0.5795
# Epoch 30: dir_acc did not improve from 0.58363
#
# Epoch 30: val_dir_acc improved from 0.60477 to 0.60822, saving model to transformer_val_model.keras
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1613 - dir_acc: 0.5795 - val_loss: 0.1457 - val_dir_acc: 0.6082 - lr: 0.0048
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.005.
# Epoch 31/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1563 - dir_acc: 0.5823
# Epoch 31: dir_acc did not improve from 0.58363
#
# Epoch 31: val_dir_acc did not improve from 0.60822
# 324/324 [==============================] - 49s 151ms/step - loss: 0.1563 - dir_acc: 0.5823 - val_loss: 0.1539 - val_dir_acc: 0.5943 - lr: 0.0050
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.00499748770102058.
# Epoch 32/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1588 - dir_acc: 0.5856
# Epoch 32: dir_acc improved from 0.58363 to 0.58560, saving model to transformer_train_model.keras
#
# Epoch 32: val_dir_acc did not improve from 0.60822
# 324/324 [==============================] - 50s 154ms/step - loss: 0.1588 - dir_acc: 0.5856 - val_loss: 0.1720 - val_dir_acc: 0.5890 - lr: 0.0050
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.0049899558635181215.
# Epoch 33/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1549 - dir_acc: 0.5872
# Epoch 33: dir_acc improved from 0.58560 to 0.58719, saving model to transformer_train_model.keras
#
# Epoch 33: val_dir_acc did not improve from 0.60822
# 324/324 [==============================] - 49s 153ms/step - loss: 0.1549 - dir_acc: 0.5872 - val_loss: 0.1749 - val_dir_acc: 0.5847 - lr: 0.0050
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.004977419655610997.
# Epoch 34/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1546 - dir_acc: 0.5909
# Epoch 34: dir_acc improved from 0.58719 to 0.59092, saving model to transformer_train_model.keras
#
# Epoch 34: val_dir_acc did not improve from 0.60822
# 324/324 [==============================] - 50s 153ms/step - loss: 0.1546 - dir_acc: 0.5909 - val_loss: 0.1632 - val_dir_acc: 0.5969 - lr: 0.0050
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.004959904323553581.
# Epoch 35/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1531 - dir_acc: 0.5916
# Epoch 35: dir_acc improved from 0.59092 to 0.59160, saving model to transformer_train_model.keras
#
# Epoch 35: val_dir_acc improved from 0.60822 to 0.61600, saving model to transformer_val_model.keras
# 324/324 [==============================] - 50s 155ms/step - loss: 0.1531 - dir_acc: 0.5916 - val_loss: 0.1438 - val_dir_acc: 0.6160 - lr: 0.0050
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.0049374451408936496.
# Epoch 36/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1507 - dir_acc: 0.5975
# Epoch 36: dir_acc improved from 0.59160 to 0.59755, saving model to transformer_train_model.keras
#
# Epoch 36: val_dir_acc did not improve from 0.61600
# 324/324 [==============================] - 50s 154ms/step - loss: 0.1507 - dir_acc: 0.5975 - val_loss: 0.1534 - val_dir_acc: 0.5951 - lr: 0.0049
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.004910087337436154.
# Epoch 37/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1525 - dir_acc: 0.5863
# Epoch 37: dir_acc did not improve from 0.59755
#
# Epoch 37: val_dir_acc did not improve from 0.61600
# 324/324 [==============================] - 49s 151ms/step - loss: 0.1525 - dir_acc: 0.5863 - val_loss: 0.1466 - val_dir_acc: 0.5995 - lr: 0.0049
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.004877886008156408.
# Epoch 38/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1500 - dir_acc: 0.5965
# Epoch 38: dir_acc did not improve from 0.59755
#
# Epoch 38: val_dir_acc did not improve from 0.61600
# 324/324 [==============================] - 49s 150ms/step - loss: 0.1500 - dir_acc: 0.5965 - val_loss: 0.1580 - val_dir_acc: 0.5961 - lr: 0.0049
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.004840906002246144.
# Epoch 39/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1493 - dir_acc: 0.5954
# Epoch 39: dir_acc did not improve from 0.59755
#
# Epoch 39: val_dir_acc improved from 0.61600 to 0.62032, saving model to transformer_val_model.keras
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1493 - dir_acc: 0.5954 - val_loss: 0.1407 - val_dir_acc: 0.6203 - lr: 0.0048
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.00479922179251587.
# Epoch 40/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1481 - dir_acc: 0.6007
# Epoch 40: dir_acc improved from 0.59755 to 0.60065, saving model to transformer_train_model.keras
#
# Epoch 40: val_dir_acc did not improve from 0.62032
# 324/324 [==============================] - 50s 154ms/step - loss: 0.1481 - dir_acc: 0.6007 - val_loss: 0.1455 - val_dir_acc: 0.6186 - lr: 0.0048
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.0047529173254165355.
# Epoch 41/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1456 - dir_acc: 0.6010
# Epoch 41: dir_acc improved from 0.60065 to 0.60098, saving model to transformer_train_model.keras
#
# Epoch 41: val_dir_acc did not improve from 0.62032
# 324/324 [==============================] - 50s 154ms/step - loss: 0.1456 - dir_acc: 0.6010 - val_loss: 0.1620 - val_dir_acc: 0.5743 - lr: 0.0048
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.004702085851982562.
# Epoch 42/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1441 - dir_acc: 0.6049
# Epoch 42: dir_acc improved from 0.60098 to 0.60490, saving model to transformer_train_model.keras
#
# Epoch 42: val_dir_acc improved from 0.62032 to 0.65334, saving model to transformer_val_model.keras
# 324/324 [==============================] - 50s 155ms/step - loss: 0.1441 - dir_acc: 0.6049 - val_loss: 0.1303 - val_dir_acc: 0.6533 - lr: 0.0047
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.004646829740036656.
# Epoch 43/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1451 - dir_acc: 0.6035
# Epoch 43: dir_acc did not improve from 0.60490
#
# Epoch 43: val_dir_acc did not improve from 0.65334
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1451 - dir_acc: 0.6035 - val_loss: 0.1340 - val_dir_acc: 0.6246 - lr: 0.0046
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.00458726026803465.
# Epoch 44/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1464 - dir_acc: 0.6055
# Epoch 44: dir_acc improved from 0.60490 to 0.60552, saving model to transformer_train_model.keras
#
# Epoch 44: val_dir_acc did not improve from 0.65334
# 324/324 [==============================] - 49s 153ms/step - loss: 0.1464 - dir_acc: 0.6055 - val_loss: 0.1383 - val_dir_acc: 0.6255 - lr: 0.0046
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.004523497400965494.
# Epoch 45/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1423 - dir_acc: 0.6048
# Epoch 45: dir_acc did not improve from 0.60552
#
# Epoch 45: val_dir_acc did not improve from 0.65334
# 324/324 [==============================] - 49s 151ms/step - loss: 0.1423 - dir_acc: 0.6048 - val_loss: 0.1403 - val_dir_acc: 0.6212 - lr: 0.0045
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.004455669548757734.
# Epoch 46/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1419 - dir_acc: 0.6112
# Epoch 46: dir_acc improved from 0.60552 to 0.61118, saving model to transformer_train_model.keras
#
# Epoch 46: val_dir_acc did not improve from 0.65334
# 324/324 [==============================] - 50s 153ms/step - loss: 0.1419 - dir_acc: 0.6112 - val_loss: 0.1390 - val_dir_acc: 0.6403 - lr: 0.0045
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.00438391330767901.
# Epoch 47/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1400 - dir_acc: 0.6126
# Epoch 47: dir_acc improved from 0.61118 to 0.61260, saving model to transformer_train_model.keras
#
# Epoch 47: val_dir_acc did not improve from 0.65334
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1400 - dir_acc: 0.6126 - val_loss: 0.1288 - val_dir_acc: 0.6446 - lr: 0.0044
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.004308373185249342.
# Epoch 48/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1393 - dir_acc: 0.6113
# Epoch 48: dir_acc did not improve from 0.61260
#
# Epoch 48: val_dir_acc did not improve from 0.65334
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1393 - dir_acc: 0.6113 - val_loss: 0.1464 - val_dir_acc: 0.6194 - lr: 0.0043
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.004229201309222228.
# Epoch 49/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1386 - dir_acc: 0.6159
# Epoch 49: dir_acc improved from 0.61260 to 0.61587, saving model to transformer_train_model.keras
#
# Epoch 49: val_dir_acc did not improve from 0.65334
# 324/324 [==============================] - 50s 154ms/step - loss: 0.1386 - dir_acc: 0.6159 - val_loss: 0.1404 - val_dir_acc: 0.6143 - lr: 0.0042
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.0041465571212195825.
# Epoch 50/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1384 - dir_acc: 0.6132
# Epoch 50: dir_acc did not improve from 0.61587
#
# Epoch 50: val_dir_acc did not improve from 0.65334
# 324/324 [==============================] - 49s 151ms/step - loss: 0.1384 - dir_acc: 0.6132 - val_loss: 0.1444 - val_dir_acc: 0.6160 - lr: 0.0041
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.0040606070556375405.
# Epoch 51/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1398 - dir_acc: 0.6139
# Epoch 51: dir_acc did not improve from 0.61587
#
# Epoch 51: val_dir_acc did not improve from 0.65334
# 324/324 [==============================] - 49s 151ms/step - loss: 0.1398 - dir_acc: 0.6139 - val_loss: 0.1325 - val_dir_acc: 0.6307 - lr: 0.0041
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.00397152420446972.
# Epoch 52/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1370 - dir_acc: 0.6178
# Epoch 52: dir_acc improved from 0.61587 to 0.61782, saving model to transformer_train_model.keras
#
# Epoch 52: val_dir_acc did not improve from 0.65334
# 324/324 [==============================] - 49s 153ms/step - loss: 0.1370 - dir_acc: 0.6178 - val_loss: 0.1361 - val_dir_acc: 0.6334 - lr: 0.0040
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.0038794879687229964.
# Epoch 53/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1368 - dir_acc: 0.6143
# Epoch 53: dir_acc did not improve from 0.61782
#
# Epoch 53: val_dir_acc did not improve from 0.65334
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1368 - dir_acc: 0.6143 - val_loss: 0.1393 - val_dir_acc: 0.5908 - lr: 0.0039
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.0037846836971277367.
# Epoch 54/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1368 - dir_acc: 0.6161
# Epoch 54: dir_acc did not improve from 0.61782
#
# Epoch 54: val_dir_acc did not improve from 0.65334
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1368 - dir_acc: 0.6161 - val_loss: 0.1424 - val_dir_acc: 0.6116 - lr: 0.0038
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.003687302312870132.
# Epoch 55/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1354 - dir_acc: 0.6201
# Epoch 55: dir_acc improved from 0.61782 to 0.62014, saving model to transformer_train_model.keras
#
# Epoch 55: val_dir_acc did not improve from 0.65334
# 324/324 [==============================] - 50s 154ms/step - loss: 0.1354 - dir_acc: 0.6201 - val_loss: 0.1478 - val_dir_acc: 0.6081 - lr: 0.0037
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.0035875399290983077.
# Epoch 56/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1321 - dir_acc: 0.6253
# Epoch 56: dir_acc improved from 0.62014 to 0.62526, saving model to transformer_train_model.keras
#
# Epoch 56: val_dir_acc did not improve from 0.65334
# 324/324 [==============================] - 50s 154ms/step - loss: 0.1321 - dir_acc: 0.6253 - val_loss: 0.1393 - val_dir_acc: 0.6168 - lr: 0.0036
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.00348559745397654.
# Epoch 57/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1317 - dir_acc: 0.6245
# Epoch 57: dir_acc did not improve from 0.62526
#
# Epoch 57: val_dir_acc did not improve from 0.65334
# 324/324 [==============================] - 49s 151ms/step - loss: 0.1317 - dir_acc: 0.6245 - val_loss: 0.1224 - val_dir_acc: 0.6490 - lr: 0.0035
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.0033816801860829505.
# Epoch 58/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1307 - dir_acc: 0.6271
# Epoch 58: dir_acc improved from 0.62526 to 0.62714, saving model to transformer_train_model.keras
#
# Epoch 58: val_dir_acc improved from 0.65334 to 0.66027, saving model to transformer_val_model.keras
# 324/324 [==============================] - 50s 156ms/step - loss: 0.1307 - dir_acc: 0.6271 - val_loss: 0.1242 - val_dir_acc: 0.6603 - lr: 0.0034
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.0032759974009654944.
# Epoch 59/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1309 - dir_acc: 0.6275
# Epoch 59: dir_acc improved from 0.62714 to 0.62752, saving model to transformer_train_model.keras
#
# Epoch 59: val_dir_acc did not improve from 0.66027
# 324/324 [==============================] - 50s 153ms/step - loss: 0.1309 - dir_acc: 0.6275 - val_loss: 0.1249 - val_dir_acc: 0.6464 - lr: 0.0033
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.0031687619296888545.
# Epoch 60/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1285 - dir_acc: 0.6296
# Epoch 60: dir_acc improved from 0.62752 to 0.62961, saving model to transformer_train_model.keras
#
# Epoch 60: val_dir_acc did not improve from 0.66027
# 324/324 [==============================] - 50s 153ms/step - loss: 0.1285 - dir_acc: 0.6296 - val_loss: 0.1296 - val_dir_acc: 0.6464 - lr: 0.0032
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.003060189730221005.
# Epoch 61/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1287 - dir_acc: 0.6303
# Epoch 61: dir_acc improved from 0.62961 to 0.63025, saving model to transformer_train_model.keras
#
# Epoch 61: val_dir_acc did not improve from 0.66027
# 324/324 [==============================] - 50s 154ms/step - loss: 0.1287 - dir_acc: 0.6303 - val_loss: 0.1242 - val_dir_acc: 0.6455 - lr: 0.0031
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.002950499452522599.
# Epoch 62/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1258 - dir_acc: 0.6420
# Epoch 62: dir_acc improved from 0.63025 to 0.64197, saving model to transformer_train_model.keras
#
# Epoch 62: val_dir_acc did not improve from 0.66027
# 324/324 [==============================] - 50s 154ms/step - loss: 0.1258 - dir_acc: 0.6420 - val_loss: 0.1250 - val_dir_acc: 0.6386 - lr: 0.0030
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.0028399119982150506.
# Epoch 63/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1269 - dir_acc: 0.6349
# Epoch 63: dir_acc did not improve from 0.64197
#
# Epoch 63: val_dir_acc did not improve from 0.66027
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1269 - dir_acc: 0.6349 - val_loss: 0.1192 - val_dir_acc: 0.6542 - lr: 0.0028
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.002728650075714067.
# Epoch 64/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1257 - dir_acc: 0.6403
# Epoch 64: dir_acc did not improve from 0.64197
#
# Epoch 64: val_dir_acc did not improve from 0.66027
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1257 - dir_acc: 0.6403 - val_loss: 0.1378 - val_dir_acc: 0.6169 - lr: 0.0027
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.0026169377517245352.
# Epoch 65/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1246 - dir_acc: 0.6408
# Epoch 65: dir_acc did not improve from 0.64197
#
# Epoch 65: val_dir_acc did not improve from 0.66027
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1246 - dir_acc: 0.6408 - val_loss: 0.1217 - val_dir_acc: 0.6394 - lr: 0.0026
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.0025050000000000003.
# Epoch 66/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1234 - dir_acc: 0.6428
# Epoch 66: dir_acc improved from 0.64197 to 0.64280, saving model to transformer_train_model.keras
#
# Epoch 66: val_dir_acc did not improve from 0.66027
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1234 - dir_acc: 0.6428 - val_loss: 0.1200 - val_dir_acc: 0.6377 - lr: 0.0025
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.0023930622482754658.
# Epoch 67/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1237 - dir_acc: 0.6460
# Epoch 67: dir_acc improved from 0.64280 to 0.64599, saving model to transformer_train_model.keras
#
# Epoch 67: val_dir_acc did not improve from 0.66027
# 324/324 [==============================] - 50s 155ms/step - loss: 0.1237 - dir_acc: 0.6460 - val_loss: 0.1252 - val_dir_acc: 0.6577 - lr: 0.0024
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.002281349924285934.
# Epoch 68/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1224 - dir_acc: 0.6446
# Epoch 68: dir_acc did not improve from 0.64599
#
# Epoch 68: val_dir_acc did not improve from 0.66027
# 324/324 [==============================] - 49s 150ms/step - loss: 0.1224 - dir_acc: 0.6446 - val_loss: 0.1257 - val_dir_acc: 0.6325 - lr: 0.0023
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.00217008800178495.
# Epoch 69/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1205 - dir_acc: 0.6507
# Epoch 69: dir_acc improved from 0.64599 to 0.65068, saving model to transformer_train_model.keras
#
# Epoch 69: val_dir_acc did not improve from 0.66027
# 324/324 [==============================] - 50s 153ms/step - loss: 0.1205 - dir_acc: 0.6507 - val_loss: 0.1185 - val_dir_acc: 0.6551 - lr: 0.0022
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.002059500547477402.
# Epoch 70/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1203 - dir_acc: 0.6510
# Epoch 70: dir_acc improved from 0.65068 to 0.65102, saving model to transformer_train_model.keras
#
# Epoch 70: val_dir_acc did not improve from 0.66027
# 324/324 [==============================] - 49s 153ms/step - loss: 0.1203 - dir_acc: 0.6510 - val_loss: 0.1240 - val_dir_acc: 0.6264 - lr: 0.0021
#
# Epoch 71: LearningRateScheduler setting learning rate to 0.001949810269778996.
# Epoch 71/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1180 - dir_acc: 0.6542
# Epoch 71: dir_acc improved from 0.65102 to 0.65423, saving model to transformer_train_model.keras
#
# Epoch 71: val_dir_acc improved from 0.66027 to 0.66551, saving model to transformer_val_model.keras
# 324/324 [==============================] - 50s 154ms/step - loss: 0.1180 - dir_acc: 0.6542 - val_loss: 0.1217 - val_dir_acc: 0.6655 - lr: 0.0019
#
# Epoch 72: LearningRateScheduler setting learning rate to 0.0018412380703111465.
# Epoch 72/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1184 - dir_acc: 0.6566
# Epoch 72: dir_acc improved from 0.65423 to 0.65659, saving model to transformer_train_model.keras
#
# Epoch 72: val_dir_acc did not improve from 0.66551
# 324/324 [==============================] - 50s 153ms/step - loss: 0.1184 - dir_acc: 0.6566 - val_loss: 0.1180 - val_dir_acc: 0.6568 - lr: 0.0018
#
# Epoch 73: LearningRateScheduler setting learning rate to 0.0017340025990345066.
# Epoch 73/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1181 - dir_acc: 0.6597
# Epoch 73: dir_acc improved from 0.65659 to 0.65971, saving model to transformer_train_model.keras
#
# Epoch 73: val_dir_acc improved from 0.66551 to 0.66639, saving model to transformer_val_model.keras
# 324/324 [==============================] - 50s 154ms/step - loss: 0.1181 - dir_acc: 0.6597 - val_loss: 0.1144 - val_dir_acc: 0.6664 - lr: 0.0017
#
# Epoch 74: LearningRateScheduler setting learning rate to 0.0016283198139170505.
# Epoch 74/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1160 - dir_acc: 0.6623
# Epoch 74: dir_acc improved from 0.65971 to 0.66233, saving model to transformer_train_model.keras
#
# Epoch 74: val_dir_acc did not improve from 0.66639
# 324/324 [==============================] - 50s 153ms/step - loss: 0.1160 - dir_acc: 0.6623 - val_loss: 0.1145 - val_dir_acc: 0.6568 - lr: 0.0016
#
# Epoch 75: LearningRateScheduler setting learning rate to 0.0015244025460234615.
# Epoch 75/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1159 - dir_acc: 0.6656
# Epoch 75: dir_acc improved from 0.66233 to 0.66565, saving model to transformer_train_model.keras
#
# Epoch 75: val_dir_acc improved from 0.66639 to 0.67510, saving model to transformer_val_model.keras
# 324/324 [==============================] - 50s 155ms/step - loss: 0.1159 - dir_acc: 0.6656 - val_loss: 0.1118 - val_dir_acc: 0.6751 - lr: 0.0015
#
# Epoch 76: LearningRateScheduler setting learning rate to 0.001422460070901693.
# Epoch 76/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1153 - dir_acc: 0.6617
# Epoch 76: dir_acc did not improve from 0.66565
#
# Epoch 76: val_dir_acc did not improve from 0.67510
# 324/324 [==============================] - 49s 151ms/step - loss: 0.1153 - dir_acc: 0.6617 - val_loss: 0.1178 - val_dir_acc: 0.6473 - lr: 0.0014
#
# Epoch 77: LearningRateScheduler setting learning rate to 0.0013226976871298685.
# Epoch 77/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1149 - dir_acc: 0.6686
# Epoch 77: dir_acc improved from 0.66565 to 0.66859, saving model to transformer_train_model.keras
#
# Epoch 77: val_dir_acc did not improve from 0.67510
# 324/324 [==============================] - 50s 153ms/step - loss: 0.1149 - dir_acc: 0.6686 - val_loss: 0.1112 - val_dir_acc: 0.6595 - lr: 0.0013
#
# Epoch 78: LearningRateScheduler setting learning rate to 0.0012253163028722645.
# Epoch 78/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1133 - dir_acc: 0.6705
# Epoch 78: dir_acc improved from 0.66859 to 0.67053, saving model to transformer_train_model.keras
#
# Epoch 78: val_dir_acc did not improve from 0.67510
# 324/324 [==============================] - 49s 153ms/step - loss: 0.1133 - dir_acc: 0.6705 - val_loss: 0.1111 - val_dir_acc: 0.6681 - lr: 0.0012
#
# Epoch 79: LearningRateScheduler setting learning rate to 0.0011305120312770046.
# Epoch 79/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1138 - dir_acc: 0.6744
# Epoch 79: dir_acc improved from 0.67053 to 0.67439, saving model to transformer_train_model.keras
#
# Epoch 79: val_dir_acc improved from 0.67510 to 0.67679, saving model to transformer_val_model.keras
# 324/324 [==============================] - 51s 156ms/step - loss: 0.1138 - dir_acc: 0.6744 - val_loss: 0.1117 - val_dir_acc: 0.6768 - lr: 0.0011
#
# Epoch 80: LearningRateScheduler setting learning rate to 0.00103847579553028.
# Epoch 80/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1124 - dir_acc: 0.6734
# Epoch 80: dir_acc did not improve from 0.67439
#
# Epoch 80: val_dir_acc did not improve from 0.67679
# 324/324 [==============================] - 49s 151ms/step - loss: 0.1124 - dir_acc: 0.6734 - val_loss: 0.1127 - val_dir_acc: 0.6646 - lr: 0.0010
#
# Epoch 81: LearningRateScheduler setting learning rate to 0.00094939294436246.
# Epoch 81/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1111 - dir_acc: 0.6730
# Epoch 81: dir_acc did not improve from 0.67439
#
# Epoch 81: val_dir_acc did not improve from 0.67679
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1111 - dir_acc: 0.6730 - val_loss: 0.1098 - val_dir_acc: 0.6586 - lr: 9.4939e-04
#
# Epoch 82: LearningRateScheduler setting learning rate to 0.0008634428787804172.
# Epoch 82/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1105 - dir_acc: 0.6784
# Epoch 82: dir_acc improved from 0.67439 to 0.67836, saving model to transformer_train_model.keras
#
# Epoch 82: val_dir_acc did not improve from 0.67679
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1105 - dir_acc: 0.6784 - val_loss: 0.1097 - val_dir_acc: 0.6751 - lr: 8.6344e-04
#
# Epoch 83: LearningRateScheduler setting learning rate to 0.0007807986907777728.
# Epoch 83/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1100 - dir_acc: 0.6805
# Epoch 83: dir_acc improved from 0.67836 to 0.68053, saving model to transformer_train_model.keras
#
# Epoch 83: val_dir_acc did not improve from 0.67679
# 324/324 [==============================] - 50s 153ms/step - loss: 0.1100 - dir_acc: 0.6805 - val_loss: 0.1096 - val_dir_acc: 0.6629 - lr: 7.8080e-04
#
# Epoch 84: LearningRateScheduler setting learning rate to 0.0007016268147506584.
# Epoch 84/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1096 - dir_acc: 0.6804
# Epoch 84: dir_acc did not improve from 0.68053
#
# Epoch 84: val_dir_acc did not improve from 0.67679
# 324/324 [==============================] - 49s 151ms/step - loss: 0.1096 - dir_acc: 0.6804 - val_loss: 0.1092 - val_dir_acc: 0.6594 - lr: 7.0163e-04
#
# Epoch 85: LearningRateScheduler setting learning rate to 0.000626086692320991.
# Epoch 85/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1090 - dir_acc: 0.6804
# Epoch 85: dir_acc did not improve from 0.68053
#
# Epoch 85: val_dir_acc did not improve from 0.67679
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1090 - dir_acc: 0.6804 - val_loss: 0.1072 - val_dir_acc: 0.6681 - lr: 6.2609e-04
#
# Epoch 86: LearningRateScheduler setting learning rate to 0.0005543304512422657.
# Epoch 86/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1090 - dir_acc: 0.6826
# Epoch 86: dir_acc improved from 0.68053 to 0.68262, saving model to transformer_train_model.keras
#
# Epoch 86: val_dir_acc improved from 0.67679 to 0.67943, saving model to transformer_val_model.keras
# 324/324 [==============================] - 50s 154ms/step - loss: 0.1090 - dir_acc: 0.6826 - val_loss: 0.1085 - val_dir_acc: 0.6794 - lr: 5.5433e-04
#
# Epoch 87: LearningRateScheduler setting learning rate to 0.00048650259903450645.
# Epoch 87/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1080 - dir_acc: 0.6825
# Epoch 87: dir_acc did not improve from 0.68262
#
# Epoch 87: val_dir_acc did not improve from 0.67943
# 324/324 [==============================] - 49s 151ms/step - loss: 0.1080 - dir_acc: 0.6825 - val_loss: 0.1063 - val_dir_acc: 0.6707 - lr: 4.8650e-04
#
# Epoch 88: LearningRateScheduler setting learning rate to 0.00042273973196535.
# Epoch 88/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1077 - dir_acc: 0.6817
# Epoch 88: dir_acc did not improve from 0.68262
#
# Epoch 88: val_dir_acc did not improve from 0.67943
# 324/324 [==============================] - 49s 150ms/step - loss: 0.1077 - dir_acc: 0.6817 - val_loss: 0.1080 - val_dir_acc: 0.6673 - lr: 4.2274e-04
#
# Epoch 89: LearningRateScheduler setting learning rate to 0.00036317025996334415.
# Epoch 89/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1076 - dir_acc: 0.6867
# Epoch 89: dir_acc improved from 0.68262 to 0.68666, saving model to transformer_train_model.keras
#
# Epoch 89: val_dir_acc did not improve from 0.67943
# 324/324 [==============================] - 50s 154ms/step - loss: 0.1076 - dir_acc: 0.6867 - val_loss: 0.1074 - val_dir_acc: 0.6664 - lr: 3.6317e-04
#
# Epoch 90: LearningRateScheduler setting learning rate to 0.00030791414801743875.
# Epoch 90/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1074 - dir_acc: 0.6855
# Epoch 90: dir_acc did not improve from 0.68666
#
# Epoch 90: val_dir_acc improved from 0.67943 to 0.67944, saving model to transformer_val_model.keras
# 324/324 [==============================] - 50s 153ms/step - loss: 0.1074 - dir_acc: 0.6855 - val_loss: 0.1064 - val_dir_acc: 0.6794 - lr: 3.0791e-04
#
# Epoch 91: LearningRateScheduler setting learning rate to 0.00025708267458346456.
# Epoch 91/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1068 - dir_acc: 0.6895
# Epoch 91: dir_acc improved from 0.68666 to 0.68949, saving model to transformer_train_model.keras
#
# Epoch 91: val_dir_acc did not improve from 0.67944
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1068 - dir_acc: 0.6895 - val_loss: 0.1064 - val_dir_acc: 0.6777 - lr: 2.5708e-04
#
# Epoch 92: LearningRateScheduler setting learning rate to 0.00021077820748413085.
# Epoch 92/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1065 - dir_acc: 0.6899
# Epoch 92: dir_acc improved from 0.68949 to 0.68994, saving model to transformer_train_model.keras
#
# Epoch 92: val_dir_acc did not improve from 0.67944
# 324/324 [==============================] - 50s 153ms/step - loss: 0.1065 - dir_acc: 0.6899 - val_loss: 0.1073 - val_dir_acc: 0.6794 - lr: 2.1078e-04
#
# Epoch 93: LearningRateScheduler setting learning rate to 0.00016909399775385568.
# Epoch 93/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1059 - dir_acc: 0.6908
# Epoch 93: dir_acc improved from 0.68994 to 0.69080, saving model to transformer_train_model.keras
#
# Epoch 93: val_dir_acc did not improve from 0.67944
# 324/324 [==============================] - 50s 154ms/step - loss: 0.1059 - dir_acc: 0.6908 - val_loss: 0.1051 - val_dir_acc: 0.6759 - lr: 1.6909e-04
#
# Epoch 94: LearningRateScheduler setting learning rate to 0.00013211399184359196.
# Epoch 94/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1059 - dir_acc: 0.6906
# Epoch 94: dir_acc did not improve from 0.69080
#
# Epoch 94: val_dir_acc improved from 0.67944 to 0.68288, saving model to transformer_val_model.keras
# 324/324 [==============================] - 50s 153ms/step - loss: 0.1059 - dir_acc: 0.6906 - val_loss: 0.1053 - val_dir_acc: 0.6829 - lr: 1.3211e-04
#
# Epoch 95: LearningRateScheduler setting learning rate to 9.991266256384617e-05.
# Epoch 95/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1055 - dir_acc: 0.6942
# Epoch 95: dir_acc improved from 0.69080 to 0.69416, saving model to transformer_train_model.keras
#
# Epoch 95: val_dir_acc did not improve from 0.68288
# 324/324 [==============================] - 49s 153ms/step - loss: 0.1055 - dir_acc: 0.6942 - val_loss: 0.1064 - val_dir_acc: 0.6768 - lr: 9.9913e-05
#
# Epoch 96: LearningRateScheduler setting learning rate to 7.255485910635008e-05.
# Epoch 96/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1054 - dir_acc: 0.6917
# Epoch 96: dir_acc did not improve from 0.69416
#
# Epoch 96: val_dir_acc improved from 0.68288 to 0.68463, saving model to transformer_val_model.keras
# 324/324 [==============================] - 50s 154ms/step - loss: 0.1054 - dir_acc: 0.6917 - val_loss: 0.1046 - val_dir_acc: 0.6846 - lr: 7.2555e-05
#
# Epoch 97: LearningRateScheduler setting learning rate to 5.009567644641898e-05.
# Epoch 97/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1053 - dir_acc: 0.6891
# Epoch 97: dir_acc did not improve from 0.69416
#
# Epoch 97: val_dir_acc did not improve from 0.68463
# 324/324 [==============================] - 49s 151ms/step - loss: 0.1053 - dir_acc: 0.6891 - val_loss: 0.1046 - val_dir_acc: 0.6811 - lr: 5.0096e-05
#
# Epoch 98: LearningRateScheduler setting learning rate to 3.258034438900293e-05.
# Epoch 98/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1052 - dir_acc: 0.6886
# Epoch 98: dir_acc did not improve from 0.69416
#
# Epoch 98: val_dir_acc improved from 0.68463 to 0.68549, saving model to transformer_val_model.keras
# 324/324 [==============================] - 49s 152ms/step - loss: 0.1052 - dir_acc: 0.6886 - val_loss: 0.1045 - val_dir_acc: 0.6855 - lr: 3.2580e-05
#
# Epoch 99: LearningRateScheduler setting learning rate to 2.0044136481878526e-05.
# Epoch 99/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1049 - dir_acc: 0.6986
# Epoch 99: dir_acc improved from 0.69416 to 0.69856, saving model to transformer_train_model.keras
#
# Epoch 99: val_dir_acc did not improve from 0.68549
# 324/324 [==============================] - 50s 153ms/step - loss: 0.1049 - dir_acc: 0.6986 - val_loss: 0.1047 - val_dir_acc: 0.6803 - lr: 2.0044e-05
#
# Epoch 100: LearningRateScheduler setting learning rate to 1.25122989794201e-05.
# Epoch 100/100
# 324/324 [==============================] - ETA: 0s - loss: 0.1053 - dir_acc: 0.6926
# Epoch 100: dir_acc did not improve from 0.69856
#
# Epoch 100: val_dir_acc did not improve from 0.68549
# 324/324 [==============================] - 49s 151ms/step - loss: 0.1053 - dir_acc: 0.6926 - val_loss: 0.1046 - val_dir_acc: 0.6777 - lr: 1.2512e-05

# %%
# Load Weights
model.load_weights("transformer_val_model.keras")

# Make predictions
accuracy = model.evaluate(test_sequences, test_labels)[1]
print(accuracy)

# Calculate additional metrics as needed
from sklearn.metrics import r2_score

predictions = model.predict(test_sequences)
r2 = r2_score(test_labels[:, 1], predictions[:, 0])
print(f"R-squared: {r2}")
# Out:
# 36/36 [==============================] - 1s 38ms/step - loss: 0.1004 - dir_acc: 0.6542
# 0.6542338728904724
# 36/36 [==============================] - 3s 44ms/step
# R-squared: 0.9746533437479626
